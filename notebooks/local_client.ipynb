# %%
# %matplotlib notebook

import cv2 as cv
import matplotlib.pyplot as plt
from reachy_sdk import ReachySDK

# %%
reachy = ReachySDK()

# %%
reachy.head_stiff

# %%
reachy.look_at(x=0.5, y=0.0, z=-0.3, duration=1.5)

# %%
reachy.look_at(x=0.5, y=0.0, z=-0.3)

# %%
quat.positions
# Out:
# [-0.9125544570086752, -1.1818406453845198, -1.0471975511965972]

# %%
reachy.neck_disk_bottom.compliant = False
reachy.neck_disk_middle.compliant = False
reachy.neck_disk_top.compliant = False

# %%
plt.figure()

plt.imshow(cv.rotate(cv.cvtColor(reachy.left_image, cv.COLOR_BGR2RGB), rotateCode=cv.ROTATE_90_CLOCKWISE))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
reachy.neck_disk_bottom.goal_position = quat.positions[0]
reachy.neck_disk_middle.goal_position = quat.positions[1]
reachy.neck_disk_top.goal_position = quat.positions[2]

# %%
reachy.neck_disk_bottom.goal_position = -1.0
reachy.neck_disk_bottom.goal_position = -1.0
reachy.neck_disk_bottom.goal_position = -1.0

# %%
from reachy_pyluos_hal.reachy import Reachy

# %%
from logging import getLogger

# %%
r = Reachy(getLogger())

# %%
r.start()

# %%
r.set_orbita_values('zero', 'neck', {})
