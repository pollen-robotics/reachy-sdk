# %%
# %matplotlib inline

from matplotlib import pyplot as plt

# %%
from reachy_sdk import ReachySDK

robot = ReachySDK(host='192.168.86.43')

# %%
import cv2 as cv

plt.figure()
plt.imshow(cv.cvtColor(robot.left_camera.last_frame, cv.COLOR_BGR2RGB))
